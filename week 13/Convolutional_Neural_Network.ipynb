# %%
#Nama: Dilara Kynta Putri Raflita
#NIM: 1103204059
#Kelas: TK44G4

 #import git
# !wget --no-check-certificate \
  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
  -O /tmp/Chessman-image-dataset.zip
# Out:
# --2024-01-05 15:06:24--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2024-01-05 15:06:24--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   221MB/s    in 0.3s
#
# 2024-01-05 15:06:24 (221 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
#ekstrak dataset git
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
#read isi direktori dataset
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['King', 'Knight', 'Pawn', 'Bishop', 'Rook', 'Queen']

# %%
#menghitung jumlah data pada tiap direktori
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
print('total bishop images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Bishop')))
print('total queen images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Queen')))
print('total rook images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Rook')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106
# total bishop images : 87
# total queen images : 78
# total rook images : 102

# %%
#melihat salah satu sample dataset
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/Queen/00000001.jpg')
imgplot = plt.imshow(img)

# %%
#import image generator dan mengaplikasikan augmentasi gambar
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   zoom_range=0.2,
                                   shear_range=0.2,
                                   fill_mode='nearest',
                                   validation_split=0.1) #set validation split

# %%
#membagi data training dan data testing menggunakan parameter subset 'training'/'validation'
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training'
) #set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, #direktori yang sama dengan data train
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
#arsitektur model 3 layer convolution dan 2 hidden layer; 512 dan 256 unit perseptron
import tensorflow as tf
model = tf.keras.models.Sequential([
    #input shape 150x150 pixel dan 3 bytes warna
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    #flatten the result to feed into a DNN
    tf.keras.layers.Flatten(),
    #512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    #output dengan 1 neuron
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
#optimizer dan loss
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 15s - loss: 1.8183 - accuracy: 0.1884 - val_loss: 1.7875 - val_accuracy: 0.1923 - 15s/epoch - 242ms/step
# Epoch 2/50
# 63/63 - 8s - loss: 1.7854 - accuracy: 0.1924 - val_loss: 1.7732 - val_accuracy: 0.3077 - 8s/epoch - 128ms/step
# Epoch 3/50
# 63/63 - 7s - loss: 1.7482 - accuracy: 0.2445 - val_loss: 1.7303 - val_accuracy: 0.2885 - 7s/epoch - 108ms/step
# Epoch 4/50
# 63/63 - 8s - loss: 1.7139 - accuracy: 0.2705 - val_loss: 1.6929 - val_accuracy: 0.3077 - 8s/epoch - 129ms/step
# Epoch 5/50
# 63/63 - 7s - loss: 1.6741 - accuracy: 0.3026 - val_loss: 1.7094 - val_accuracy: 0.2692 - 7s/epoch - 107ms/step
# Epoch 6/50
# 63/63 - 8s - loss: 1.6385 - accuracy: 0.2966 - val_loss: 1.6363 - val_accuracy: 0.3077 - 8s/epoch - 126ms/step
# Epoch 7/50
# 63/63 - 8s - loss: 1.6121 - accuracy: 0.3307 - val_loss: 1.6900 - val_accuracy: 0.2308 - 8s/epoch - 124ms/step
# Epoch 8/50
# 63/63 - 7s - loss: 1.5524 - accuracy: 0.3667 - val_loss: 1.6906 - val_accuracy: 0.2885 - 7s/epoch - 115ms/step
# Epoch 9/50
# 63/63 - 8s - loss: 1.5599 - accuracy: 0.3587 - val_loss: 1.5800 - val_accuracy: 0.3269 - 8s/epoch - 125ms/step
# Epoch 10/50
# 63/63 - 7s - loss: 1.4752 - accuracy: 0.4108 - val_loss: 1.7335 - val_accuracy: 0.2500 - 7s/epoch - 106ms/step
# Epoch 11/50
# 63/63 - 7s - loss: 1.4528 - accuracy: 0.4248 - val_loss: 1.9713 - val_accuracy: 0.3077 - 7s/epoch - 105ms/step
# Epoch 12/50
# 63/63 - 8s - loss: 1.4295 - accuracy: 0.4349 - val_loss: 1.6206 - val_accuracy: 0.2885 - 8s/epoch - 125ms/step
# Epoch 13/50
# 63/63 - 7s - loss: 1.3283 - accuracy: 0.5030 - val_loss: 1.4512 - val_accuracy: 0.4231 - 7s/epoch - 107ms/step
# Epoch 14/50
# 63/63 - 8s - loss: 1.2853 - accuracy: 0.4870 - val_loss: 1.6071 - val_accuracy: 0.3462 - 8s/epoch - 126ms/step
# Epoch 15/50
# 63/63 - 7s - loss: 1.2585 - accuracy: 0.4810 - val_loss: 1.6951 - val_accuracy: 0.4038 - 7s/epoch - 118ms/step
# Epoch 16/50
# 63/63 - 7s - loss: 1.1968 - accuracy: 0.5631 - val_loss: 1.4620 - val_accuracy: 0.4808 - 7s/epoch - 107ms/step
# Epoch 17/50
# 63/63 - 8s - loss: 1.1749 - accuracy: 0.5431 - val_loss: 1.8323 - val_accuracy: 0.2885 - 8s/epoch - 125ms/step
# Epoch 18/50
# 63/63 - 7s - loss: 1.2035 - accuracy: 0.5511 - val_loss: 1.5882 - val_accuracy: 0.3462 - 7s/epoch - 110ms/step
# Epoch 19/50
# 63/63 - 7s - loss: 1.1080 - accuracy: 0.5912 - val_loss: 1.7785 - val_accuracy: 0.3654 - 7s/epoch - 106ms/step
# Epoch 20/50
# 63/63 - 8s - loss: 1.0723 - accuracy: 0.5972 - val_loss: 1.6329 - val_accuracy: 0.3846 - 8s/epoch - 126ms/step
# Epoch 21/50
# 63/63 - 7s - loss: 1.0570 - accuracy: 0.6052 - val_loss: 1.7885 - val_accuracy: 0.3077 - 7s/epoch - 116ms/step
# Epoch 22/50
# 63/63 - 8s - loss: 0.9765 - accuracy: 0.6413 - val_loss: 1.6870 - val_accuracy: 0.3462 - 8s/epoch - 122ms/step
# Epoch 23/50
# 63/63 - 8s - loss: 0.8817 - accuracy: 0.6653 - val_loss: 2.0166 - val_accuracy: 0.3077 - 8s/epoch - 130ms/step
# Epoch 24/50
# 63/63 - 8s - loss: 0.8965 - accuracy: 0.6633 - val_loss: 1.5771 - val_accuracy: 0.4615 - 8s/epoch - 125ms/step
# Epoch 25/50
# 63/63 - 8s - loss: 0.8911 - accuracy: 0.6754 - val_loss: 1.6129 - val_accuracy: 0.4231 - 8s/epoch - 125ms/step
# Epoch 26/50
# 63/63 - 8s - loss: 0.8290 - accuracy: 0.6974 - val_loss: 1.8190 - val_accuracy: 0.4038 - 8s/epoch - 131ms/step
# Epoch 27/50
# 63/63 - 7s - loss: 0.8235 - accuracy: 0.6914 - val_loss: 1.7663 - val_accuracy: 0.4231 - 7s/epoch - 111ms/step
# Epoch 28/50
# 63/63 - 7s - loss: 0.7761 - accuracy: 0.7315 - val_loss: 1.6844 - val_accuracy: 0.4615 - 7s/epoch - 118ms/step
# Epoch 29/50
# 63/63 - 8s - loss: 0.8909 - accuracy: 0.7174 - val_loss: 1.5319 - val_accuracy: 0.3654 - 8s/epoch - 126ms/step
# Epoch 30/50
# 63/63 - 7s - loss: 0.7663 - accuracy: 0.7214 - val_loss: 1.8708 - val_accuracy: 0.3462 - 7s/epoch - 113ms/step
# Epoch 31/50
# 63/63 - 8s - loss: 0.6733 - accuracy: 0.7655 - val_loss: 1.6042 - val_accuracy: 0.4423 - 8s/epoch - 128ms/step
# Epoch 32/50
# 63/63 - 8s - loss: 0.7254 - accuracy: 0.7455 - val_loss: 1.6153 - val_accuracy: 0.3654 - 8s/epoch - 125ms/step
# Epoch 33/50
# 63/63 - 7s - loss: 0.6512 - accuracy: 0.7555 - val_loss: 1.3908 - val_accuracy: 0.4231 - 7s/epoch - 116ms/step
# Epoch 34/50
# 63/63 - 8s - loss: 0.6962 - accuracy: 0.7655 - val_loss: 1.9923 - val_accuracy: 0.3077 - 8s/epoch - 134ms/step
# Epoch 35/50
# 63/63 - 7s - loss: 0.6253 - accuracy: 0.7735 - val_loss: 1.7391 - val_accuracy: 0.4423 - 7s/epoch - 117ms/step
# Epoch 36/50
# 63/63 - 8s - loss: 0.7073 - accuracy: 0.7535 - val_loss: 1.5290 - val_accuracy: 0.5000 - 8s/epoch - 123ms/step
# Epoch 37/50
# 63/63 - 8s - loss: 0.5735 - accuracy: 0.8016 - val_loss: 1.6814 - val_accuracy: 0.4615 - 8s/epoch - 133ms/step
# Epoch 38/50
# 63/63 - 7s - loss: 0.5499 - accuracy: 0.8257 - val_loss: 1.5677 - val_accuracy: 0.4231 - 7s/epoch - 107ms/step
# Epoch 39/50
# 63/63 - 8s - loss: 0.5314 - accuracy: 0.8317 - val_loss: 1.5552 - val_accuracy: 0.4231 - 8s/epoch - 128ms/step
# Epoch 40/50
# 63/63 - 8s - loss: 0.5879 - accuracy: 0.7796 - val_loss: 1.5799 - val_accuracy: 0.5000 - 8s/epoch - 127ms/step
# Epoch 41/50
# 63/63 - 7s - loss: 0.6014 - accuracy: 0.7816 - val_loss: 1.4578 - val_accuracy: 0.5000 - 7s/epoch - 109ms/step
# Epoch 42/50
# 63/63 - 9s - loss: 0.5426 - accuracy: 0.8076 - val_loss: 1.7865 - val_accuracy: 0.4808 - 9s/epoch - 138ms/step
# Epoch 43/50
# 63/63 - 7s - loss: 0.5470 - accuracy: 0.8136 - val_loss: 1.6146 - val_accuracy: 0.4423 - 7s/epoch - 113ms/step
# Epoch 44/50
# 63/63 - 7s - loss: 0.5045 - accuracy: 0.8236 - val_loss: 1.5477 - val_accuracy: 0.5192 - 7s/epoch - 111ms/step
# Epoch 45/50
# 63/63 - 8s - loss: 0.4591 - accuracy: 0.8317 - val_loss: 1.7882 - val_accuracy: 0.4038 - 8s/epoch - 125ms/step
# Epoch 46/50
# 63/63 - 9s - loss: 0.4708 - accuracy: 0.8176 - val_loss: 1.8646 - val_accuracy: 0.4808 - 9s/epoch - 138ms/step
# Epoch 47/50
# 63/63 - 7s - loss: 0.5743 - accuracy: 0.7916 - val_loss: 2.0174 - val_accuracy: 0.4231 - 7s/epoch - 112ms/step
# Epoch 48/50
# 63/63 - 8s - loss: 0.4422 - accuracy: 0.8317 - val_loss: 1.6474 - val_accuracy: 0.5385 - 8s/epoch - 129ms/step
# Epoch 49/50
# 63/63 - 7s - loss: 0.4194 - accuracy: 0.8357 - val_loss: 1.9275 - val_accuracy: 0.4808 - 7s/epoch - 116ms/step
# Epoch 50/50
# 63/63 - 8s - loss: 0.3828 - accuracy: 0.8717 - val_loss: 1.8596 - val_accuracy: 0.4615 - 8s/epoch - 129ms/step

# %%
#plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#plot akurasi
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
